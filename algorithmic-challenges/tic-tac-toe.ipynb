# %% [markdown]
# ## Implement a standard Tic Tac Toe Game.

# %%
class TicTacToe:
  def __init__(self):
    self.row_1 = ['', '-', '']
    self.row_2 = ['-', '', '-']
    self.row_3 = ['', '-', '']
    self.board = [self.row_1, self.row_2, self.row_3]
    self.last_player = 'O'

  def move(self, i, j):
    #alternate between players
    if self.last_player == 'O':
      self.board[i][j] = 'X'
      self.last_player = 'X'
    else:
      self.board[i][j] = 'O'
      self.last_player = 'O'
    #check winner
    winner = self.check_for_win()
    print('Winner : {}'.format(winner))

  def check_for_win(self):
    #row win
    for i in range(3):
      if self.board[i][0] == self.board[i][1] == self.board[i][2]:
        if self.board[i][0] == 'X':
          return self.board[i][0]
        elif self.board[i][0] == 'O':
          return self.board[i][0]

    #column win
    for j in range(3):
      if self.board[0][j] == self.board[1][j] == self.board[2][j]:
        if self.board[0][j] == 'X':
          return self.board[0][j]
        elif self.board[0][j] == 'O':
          return self.board[0][j]
    
    #diagonal win condition 1
    #if self.board[0][0] == self.board[1][1] == self.board[2][2]:
    
    #diagonal win condition 2
    #if self.board[0][2] == self.board[1][1] == self.board[2][0]:

    #check if all coords are filled
    return 'Draw'

  def check_for_draw(self):
    ''' No winner possible '''
    pass

  #Further improvements:
  #cannot overwrite
  #check for early draw
  #check for invalid position


t = TicTacToe()
print(t.board)
t.move(0, 0) # p1
print(t.board)
t.move(2, 0) # p2
print(t.board)
t.move(0, 1)
print(t.board)
t.move(2, 1)
print(t.board)
t.move(0, 2)
print(t.board)
t.move(2, 2)
